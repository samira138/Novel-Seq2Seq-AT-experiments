# %%
import torch
import torch.utils.data
import time
import numpy as np
import random
import os
import matplotlib.pyplot as plt
from alive_progress import alive_bar
from sklearn.preprocessing import StandardScaler , MinMaxScaler 
import sys 

sys.path.append(r"H:\Projects\Edit-Novel-Seq2Seq-Module-master")

# فراخوانی کلاس DataPrepare از ماژول preparedata
import prepare_data.prepare_data_featuresengineeringnew as prepare_data
from prepare_data.prepare_data_featuresengineeringnew  import DataPrepare
from Novel_Seq2Seq.model import stack


DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("DEVICE:", DEVICE)
# Out:
# DEVICE: cpu
# h:\Projects\Edit-Novel-Seq2Seq-Module-master\.venv\Lib\site-packages\torch\__init__.py:1275: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\tensor\python_tensor.cpp:436.)
#   _C._set_default_tensor_type(t)

# %%
import numpy as np
class MyMetrics:
    def __init__(self, y_pred, y_true, scaler_y):

        self.y_pred = y_pred
        self.y_true = y_true
        self.scaler_y = scaler_y
        self.metrics = {}
        self.mse()
        self.mape()
        self.smape()

    def mse(self):
        self.metrics['mse'] = np.mean((self.y_pred - self.y_true) ** 2)

    def mape(self):
        
       y_pred = self.scaler_y.inverse_transform(self.y_pred.reshape(-1,1)).flatten()
       y_true = self.scaler_y.inverse_transform(self.y_true.reshape(-1,1)).flatten()

       eps = 1e-8  # جلوگیری از تقسیم بر صفر
       self.metrics['mape'] = np.mean(np.abs((y_pred - y_true) / (y_true+eps))) * 100

    def smape(self):

        y_pred = self.scaler_y.inverse_transform(self.y_pred.reshape(-1,1)).flatten()
        y_true = self.scaler_y.inverse_transform(self.y_true.reshape(-1,1)).flatten()
        
        eps = 1e-8  # جلوگیری از تقسیم بر صفر
        self.metrics['smape'] = 100.0 * np.mean(
        2.0 * np.abs(y_pred - y_true) /
        (np.abs(y_pred) + np.abs(y_true) + eps)
        )

    def print_metrics(self):
        for key, values in self.metrics.items():
            print(f"The {key} is:{values}.")

# %%
class Train:
    def __init__(self, hyperparams, model, optimizer, loss_func):
        # پارامترهای دیتاست
        self.datapath       = hyperparams['datapath']
        self.datafile       = hyperparams['datafile']
        self.split_ratio    = hyperparams['split_ratio']

        # هایپرپارامترها
        self.N_EPOCHS       = hyperparams['N_EPOCHS']
        self.lr             = hyperparams['lr']
        self.batch_size     = hyperparams['batch_size']
        self.input_seqlen   = hyperparams['input_seqlen']
        self.predict_seqlen = hyperparams['predict_seqlen']
        self.features       = hyperparams['features']

        # آماده‌سازی داده
        self.dataprepare =  DataPrepare(
            datapath      = self.datapath,
            datafile      = self.datafile,
            input_steps   = self.input_seqlen,
            pred_horizion = self.predict_seqlen,
            split_ratio   = self.split_ratio
        )

        # دیتالودرها
        self.train_generator = None
        self.valid_generator = None
        self.test_generator  = None

        # مدل/بهینه‌ساز/تابع ضرر
        self.model     = model
        self.optimizer = optimizer
        self.loss_func = loss_func

        # loss تاریخچه‌ی توابع
        self.train_loss = []
        self.valid_loss = []
        self.mse        = 0
        self.scaler_y = self.dataprepare.scaler_y
        #  مسیر ذخیره
        self.save_dir = os.path.join(os.getcwd(), "trained_file")
        os.makedirs(self.save_dir, exist_ok=True)

        # seed
        self._setup_seed(20)

        # ساخت دیتالودرها
        self._prepare_data()


#DataPrepare → داده خام رو می‌خونه، تمیز می‌کنه و تقسیم می‌کنه
#Datasets →  تبدیل می‌کنهPyTorch  داده رو به فرمت
#DataLoader → داده رو دسته‌بندی می‌کنه برای آموزش

    def _prepare_data(self):
        # خروجی prepare_data: (train_ip, train_op, valid_ip, valid_op, test_ip, test_op)
        tvt_data = self.dataprepare.prepare_data()
        self.dataprepare.train_data = tvt_data[0] # Store train_data as attribute
        train_dataset = prepare_data.Datasets(tvt_data[0], tvt_data[1])
        valid_dataset = prepare_data.Datasets(tvt_data[2], tvt_data[3])
        test_dataset  = prepare_data.Datasets(tvt_data[4], tvt_data[5])

        self.train_generator = torch.utils.data.DataLoader(train_dataset, batch_size=self.batch_size, shuffle=False)
        self.valid_generator = torch.utils.data.DataLoader(valid_dataset, batch_size=self.batch_size, shuffle=False)
        self.test_generator  = torch.utils.data.DataLoader(test_dataset,  batch_size=2048, shuffle=False)

    def _ckpt_path(self):
        # نام فایل چک‌پوینت
        name = f'{self.datafile}-{self.input_seqlen}to{self.predict_seqlen}-featuresengineering.pt'
        return os.path.join(self.save_dir, name)

    #def save_state(self, state):
        #torch.save(state, self._ckpt_path())

    #def load_state(self):
        #print("Loading model and optimizer state")
        #state = torch.load(self._ckpt_path(), map_location="cpu")
        #self.model.load_state_dict(state['model'])
        #self.optimizer.load_state_dict(state['optimizer'])
        #self.train_loss = state['train_loss']
        #self.valid_loss = state['valid_loss']
        #self.mse        = state['mse']
        #self.dataprepare= state['dataprepare']



    def save_state(self, state, filename=None):
        if filename is None:
            filepath = self._ckpt_path()
        else:
            filepath = os.path.join(self.save_dir, filename)

        state["epoch"] = state.get("epoch", 0)
        torch.save(state, filepath)
        print(f"Checkpoint saved to {filepath}")



    def load_state(self, filename=None):
        if filename is None:
            filepath = self._ckpt_path()
        else:
            filepath = os.path.join(self.save_dir, filename)

        print(f"Loading checkpoint from {filepath}")
        state = torch.load(filepath, map_location=DEVICE, weights_only=False)

        self.model.load_state_dict(state['model'])
        self.optimizer.load_state_dict(state['optimizer'])
        self.train_loss = state['train_loss']
        self.valid_loss = state['valid_loss']
        self.mse        = state['mse']

        # اگر لازم داری:
        self._prepare_data()
        self.start_epoch = state.get("epoch_saved", 0)


    def _train(self):
        """
        params:
                None
        returns:
            每个样本的平均损失值
        """
        self.model.train()
        epoch_loss = 0

        for i, (x, y) in enumerate(self.train_generator):
            x = x.to(DEVICE)  # [batch_size, seq_len, feature]
            y = y.to(DEVICE)  # [batch_size, predict_seqlen]

            self.optimizer.zero_grad()
            # 输入到模型的是[batch_size, seq_len, features],模型输出是[batch_size,predict_seqlen, 1]
            output, residual = self.model(x)
            loss = self.loss_func(output.squeeze(dim=2), y) # + torch.mean(torch.abs(residual)) # output [batch_size, predict_seqlen]
            loss.backward()
            self.optimizer.step()
            epoch_loss += loss.item()
        # len(train_generator) 是 批次数量  即 样本总数/batch_size
        return epoch_loss / len(self.train_generator)



    def _evalute(self):
        self.model.eval()
        epoch_loss = 0.0
        with torch.no_grad():       #چوتن در پای تورچ گرادیان ها با گرادیان قبلی جمع میشود
            for x, y in self.valid_generator:
                x = x.to(DEVICE)
                y = y.to(DEVICE)
                output, _ = self.model(x)  # [B, pred_len, 1]
                loss = self.loss_func(output.squeeze(2), y)
                epoch_loss += loss.item()
        return epoch_loss / len(self.valid_generator)

    def _epoch_time(self, start_time, end_time):
        elapsed = end_time - start_time
        return int(elapsed // 60), int(elapsed % 60)
# قابلیت تکرارپذیری نتایج
    def _setup_seed(self, seed):
         torch.manual_seed(seed)
         torch.cuda.manual_seed_all(seed)
         np.random.seed(seed)
         random.seed(seed)
         torch.backends.cudnn.deterministic = True

    def train_model(self):
        best_valid_loss = float('inf')
        start_epoch = getattr(self, "start_epoch", 0)   # اگر load_state شده باشه از ادامه شروع کن
        print(f'DEVICE: {DEVICE}')

        with alive_bar(total=self.N_EPOCHS, title='training') as bar:
            for epoch in range(start_epoch, self.N_EPOCHS):
              start_time = time.time()

              train_loss = self._train()
              valid_loss = self._evalute()

              self.train_loss.append(train_loss)
              self.valid_loss.append(valid_loss)

              epoch_mins, epoch_secs = self._epoch_time(start_time, time.time())

            # ذخیره بهترین مدل
              if best_valid_loss > valid_loss:
                best_valid_loss = valid_loss
                self.mse = valid_loss
                state = {
                    'model'      : self.model.state_dict(),
                    'optimizer'  : self.optimizer.state_dict(),
                    'train_loss' : self.train_loss,
                    'valid_loss' : self.valid_loss,
                    'dataprepare': self.dataprepare,
                    'mse'        : self.mse,
                    'epoch_saved': epoch + 1
                }
                self.save_state(state, filename=f"{self.datafile}-{self.input_seqlen}to{self.predict_seqlen}-best.pt")
                print(f"✅ Best model updated at epoch {epoch+1} | Val Loss: {valid_loss:.4f}")

            # ذخیره آخرین ایپاک (همیشه)
              last_state = {
                'model'      : self.model.state_dict(),
                'optimizer'  : self.optimizer.state_dict(),
                'train_loss' : self.train_loss,
                'valid_loss' : self.valid_loss,
                'dataprepare': self.dataprepare,
                'mse'        : valid_loss,
                'epoch_saved': epoch + 1
              }
              self.save_state(last_state, filename=f"{self.datafile}-{self.input_seqlen}to{self.predict_seqlen}-last.pt")

              print(f'Epoch: {epoch + 1:02} | Time: {epoch_mins}m {epoch_secs}s')
              print(f'\tTrain MSE_Loss: {train_loss:.4f}')
              print(f'\t Val. MSE_Loss: {valid_loss:.4f}')
              bar()



    def plot_loss(self, save: bool = False):
        fig = plt.figure(figsize=(15, 8), dpi=80)
        ax1 = fig.add_subplot(1, 1, 1)
        ax1.set_title('loss_value')
        ax1.set_xlabel('epoch')
        ax1.set_ylabel('loss')
        ax1.set_xlim(0, self.N_EPOCHS)
        ax1.plot(self.train_loss, marker='o', label='train_loss')
        ax1.plot(self.valid_loss, linestyle='--', alpha=0.7, label='valid_loss')
        ax1.legend(loc='upper left')
        if save:
            plt.savefig('loss_value.jpg', dpi=400, bbox_inches='tight')
        plt.show()

    def predict(self):
        """
        Predict on the whole test set.

        :return:
        y_hat_all, y_all  → هر کدام [num_samples, pred_len]
        """
        self.model.eval()
        y_hat_list = []
        y_list = []

        with torch.no_grad():
            for x, y in self.test_generator:
                x = x.to(DEVICE)
                y = y.to(DEVICE)

                y_hat, _ = self.model(x)      # [B, pred_len, 1]
                y_hat = y_hat.squeeze(2)      # [B, pred_len]

                y_hat_list.append(y_hat.cpu().numpy())
                y_list.append(y.cpu().numpy())

        y_hat_all = np.concatenate(y_hat_list, axis=0)
        y_all     = np.concatenate(y_list, axis=0)

        return y_hat_all, y_all

# %%
# هایپرپارامترها (طبق مقاله مقادیر H=3/6/12/24 را تغییر بده)
HyperParams = {
    'datapath'       : r"H:/Projects/Edit-Novel-Seq2Seq-Module-master/prepare_data",
    'datafile'       : 'AT_featuresengineering_final',
    'split_ratio'    : (0.8, 0.1, 0.1),
    'N_EPOCHS'       : 50,                 
    'lr'             : 1e-3,
    'batch_size'     : 64,
    'input_seqlen'   : 24,
    'predict_seqlen' : 12,
    'features'       : 11,                 # LOAD, TEMP,SIN_HOUR,COS_HOUR,...
}


def main(LOAD_PREV=False):

    # ساخت مدل مطابق کد اصلی (stack.Stack)
    model = stack.Stack(
        input_size      = HyperParams['features'],
        encoder_channels= [4,6,8,12],
        input_seqlen    = HyperParams['input_seqlen'],
        forecast_seqlen = HyperParams['predict_seqlen']
    ).to(DEVICE)

    optimizer = torch.optim.Adam(model.parameters(), lr=HyperParams['lr'])
    loss_func = torch.nn.MSELoss(reduction='mean')

    T = Train(hyperparams=HyperParams, model=model, optimizer=optimizer, loss_func=loss_func)


    if LOAD_PREV:
        print("🔄 Loading LAST checkpoint and continuing training...")
        last_filename = f"{HyperParams['datafile']}-{HyperParams['input_seqlen']}to{HyperParams['predict_seqlen']}-last.pt"
        T.load_state(filename=last_filename)
        T.train_model()
    else:
        print("🆕 Starting training from scratch...")
        T.train_model()

        

    best_filename = f"{HyperParams['datafile']}-{HyperParams['input_seqlen']}to{HyperParams['predict_seqlen']}-best.pt"
    T.load_state(filename=best_filename)
    print("✅ Loaded BEST model for final evaluation on test set.")

    # ارزیابی
    y_hat, y = T.predict()
    metrics = MyMetrics(y_hat, y, T.dataprepare.scaler_y)
    metrics.print_metrics()
    T.plot_loss()

# %%
main()
# Out:
# h:\Projects\Edit-Novel-Seq2Seq-Module-master\.venv\Lib\site-packages\torch\nn\utils\weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 🆕 Starting training from scratch...
# DEVICE: cpu
# on 0: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 0: ✅ Best model updated at epoch 1 | Val Loss: 0.0519
# on 0: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 0: Epoch: 01 | Time: 3m 44s
# on 0: 	Train MSE_Loss: 0.0313
# on 0: 	 Val. MSE_Loss: 0.0519
# on 1: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 1: ✅ Best model updated at epoch 2 | Val Loss: 0.0510
# on 1: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 1: Epoch: 02 | Time: 3m 32s
# on 1: 	Train MSE_Loss: 0.0299
# on 1: 	 Val. MSE_Loss: 0.0510
# on 2: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 2: ✅ Best model updated at epoch 3 | Val Loss: 0.0506
# on 2: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 2: Epoch: 03 | Time: 3m 33s
# on 2: 	Train MSE_Loss: 0.0302
# on 2: 	 Val. MSE_Loss: 0.0506
# on 3: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 3: ✅ Best model updated at epoch 4 | Val Loss: 0.0500
# on 3: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 3: Epoch: 04 | Time: 3m 40s
# on 3: 	Train MSE_Loss: 0.0307
# on 3: 	 Val. MSE_Loss: 0.0500
# on 4: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 4: ✅ Best model updated at epoch 5 | Val Loss: 0.0496
# on 4: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 4: Epoch: 05 | Time: 3m 44s
# on 4: 	Train MSE_Loss: 0.0310
# on 4: 	 Val. MSE_Loss: 0.0496
# on 5: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 5: ✅ Best model updated at epoch 6 | Val Loss: 0.0480
# on 5: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 5: Epoch: 06 | Time: 3m 55s
# on 5: 	Train MSE_Loss: 0.0318
# on 5: 	 Val. MSE_Loss: 0.0480
# on 6: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 6: ✅ Best model updated at epoch 7 | Val Loss: 0.0472
# on 6: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 6: Epoch: 07 | Time: 3m 51s
# on 6: 	Train MSE_Loss: 0.0325
# on 6: 	 Val. MSE_Loss: 0.0472
# on 7: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 7: ✅ Best model updated at epoch 8 | Val Loss: 0.0452
# on 7: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 7: Epoch: 08 | Time: 3m 47s
# on 7: 	Train MSE_Loss: 0.0329
# on 7: 	 Val. MSE_Loss: 0.0452
# on 8: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 8: ✅ Best model updated at epoch 9 | Val Loss: 0.0450
# on 8: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 8: Epoch: 09 | Time: 3m 46s
# on 8: 	Train MSE_Loss: 0.0322
# on 8: 	 Val. MSE_Loss: 0.0450
# on 9: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 9: ✅ Best model updated at epoch 10 | Val Loss: 0.0437
# on 9: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 9: Epoch: 10 | Time: 3m 46s
# on 9: 	Train MSE_Loss: 0.0325
# on 9: 	 Val. MSE_Loss: 0.0437
# on 10: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 10: ✅ Best model updated at epoch 11 | Val Loss: 0.0422
# on 10: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 10: Epoch: 11 | Time: 3m 48s
# on 10: 	Train MSE_Loss: 0.0335
# on 10: 	 Val. MSE_Loss: 0.0422
# on 11: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 11: ✅ Best model updated at epoch 12 | Val Loss: 0.0409
# on 11: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 11: Epoch: 12 | Time: 3m 51s
# on 11: 	Train MSE_Loss: 0.0340
# on 11: 	 Val. MSE_Loss: 0.0409
# on 12: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 12: ✅ Best model updated at epoch 13 | Val Loss: 0.0403
# on 12: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 12: Epoch: 13 | Time: 3m 50s
# on 12: 	Train MSE_Loss: 0.0341
# on 12: 	 Val. MSE_Loss: 0.0403
# on 13: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 13: ✅ Best model updated at epoch 14 | Val Loss: 0.0400
# on 13: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 13: Epoch: 14 | Time: 3m 40s
# on 13: 	Train MSE_Loss: 0.0341
# on 13: 	 Val. MSE_Loss: 0.0400
# on 14: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 14: ✅ Best model updated at epoch 15 | Val Loss: 0.0398
# on 14: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 14: Epoch: 15 | Time: 4m 16s
# on 14: 	Train MSE_Loss: 0.0342
# on 14: 	 Val. MSE_Loss: 0.0398
# on 15: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 15: ✅ Best model updated at epoch 16 | Val Loss: 0.0392
# on 15: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 15: Epoch: 16 | Time: 4m 32s
# on 15: 	Train MSE_Loss: 0.0343
# on 15: 	 Val. MSE_Loss: 0.0392
# on 16: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 16: ✅ Best model updated at epoch 17 | Val Loss: 0.0391
# on 16: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 16: Epoch: 17 | Time: 4m 37s
# on 16: 	Train MSE_Loss: 0.0344
# on 16: 	 Val. MSE_Loss: 0.0391
# on 17: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 17: Epoch: 18 | Time: 3m 42s
# on 17: 	Train MSE_Loss: 0.0340
# on 17: 	 Val. MSE_Loss: 0.0408
# on 18: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 18: Epoch: 19 | Time: 4m 29s
# on 18: 	Train MSE_Loss: 0.0342
# on 18: 	 Val. MSE_Loss: 0.0399
# on 19: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 19: Epoch: 20 | Time: 3m 52s
# on 19: 	Train MSE_Loss: 0.0343
# on 19: 	 Val. MSE_Loss: 0.0397
# on 20: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 20: Epoch: 21 | Time: 3m 49s
# on 20: 	Train MSE_Loss: 0.0342
# on 20: 	 Val. MSE_Loss: 0.0396
# on 21: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 21: Epoch: 22 | Time: 3m 37s
# on 21: 	Train MSE_Loss: 0.0343
# on 21: 	 Val. MSE_Loss: 0.0395
# on 22: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 22: Epoch: 23 | Time: 3m 52s
# on 22: 	Train MSE_Loss: 0.0343
# on 22: 	 Val. MSE_Loss: 0.0395
# on 23: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 23: Epoch: 24 | Time: 4m 2s
# on 23: 	Train MSE_Loss: 0.0338
# on 23: 	 Val. MSE_Loss: 0.0399
# on 24: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 24: Epoch: 25 | Time: 3m 46s
# on 24: 	Train MSE_Loss: 0.0341
# on 24: 	 Val. MSE_Loss: 0.0406
# on 25: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 25: Epoch: 26 | Time: 3m 48s
# on 25: 	Train MSE_Loss: 0.0340
# on 25: 	 Val. MSE_Loss: 0.0411
# on 26: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 26: Epoch: 27 | Time: 3m 53s
# on 26: 	Train MSE_Loss: 0.0340
# on 26: 	 Val. MSE_Loss: 0.0399
# on 27: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 27: Epoch: 28 | Time: 3m 57s
# on 27: 	Train MSE_Loss: 0.0343
# on 27: 	 Val. MSE_Loss: 0.0397
# on 28: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 28: Epoch: 29 | Time: 3m 50s
# on 28: 	Train MSE_Loss: 0.0342
# on 28: 	 Val. MSE_Loss: 0.0397
# on 29: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 29: Epoch: 30 | Time: 3m 55s
# on 29: 	Train MSE_Loss: 0.0343
# on 29: 	 Val. MSE_Loss: 0.0395
# on 30: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 30: Epoch: 31 | Time: 4m 1s
# on 30: 	Train MSE_Loss: 0.0343
# on 30: 	 Val. MSE_Loss: 0.0394
# on 31: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 31: Epoch: 32 | Time: 3m 54s
# on 31: 	Train MSE_Loss: 0.0343
# on 31: 	 Val. MSE_Loss: 0.0402
# on 32: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 32: Epoch: 33 | Time: 3m 53s
# on 32: 	Train MSE_Loss: 0.0342
# on 32: 	 Val. MSE_Loss: 0.0397
# on 33: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 33: ✅ Best model updated at epoch 34 | Val Loss: 0.0389
# on 33: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 33: Epoch: 34 | Time: 3m 53s
# on 33: 	Train MSE_Loss: 0.0342
# on 33: 	 Val. MSE_Loss: 0.0389
# on 34: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 34: Epoch: 35 | Time: 3m 50s
# on 34: 	Train MSE_Loss: 0.0344
# on 34: 	 Val. MSE_Loss: 0.0390
# on 35: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 35: Epoch: 36 | Time: 3m 45s
# on 35: 	Train MSE_Loss: 0.0344
# on 35: 	 Val. MSE_Loss: 0.0398
# on 36: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# on 36: ✅ Best model updated at epoch 37 | Val Loss: 0.0389
# on 36: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 36: Epoch: 37 | Time: 3m 47s
# on 36: 	Train MSE_Loss: 0.0343
# on 36: 	 Val. MSE_Loss: 0.0389
# on 37: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 37: Epoch: 38 | Time: 3m 55s
# on 37: 	Train MSE_Loss: 0.0344
# on 37: 	 Val. MSE_Loss: 0.0394
# on 38: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 38: Epoch: 39 | Time: 4m 1s
# on 38: 	Train MSE_Loss: 0.0344
# on 38: 	 Val. MSE_Loss: 0.0396
# on 39: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 39: Epoch: 40 | Time: 3m 56s
# on 39: 	Train MSE_Loss: 0.0343
# on 39: 	 Val. MSE_Loss: 0.0394
# on 40: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 40: Epoch: 41 | Time: 4m 15s
# on 40: 	Train MSE_Loss: 0.0344
# on 40: 	 Val. MSE_Loss: 0.0394
# on 41: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 41: Epoch: 42 | Time: 3m 52s
# on 41: 	Train MSE_Loss: 0.0343
# on 41: 	 Val. MSE_Loss: 0.0397
# on 42: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 42: Epoch: 43 | Time: 3m 44s
# on 42: 	Train MSE_Loss: 0.0343
# on 42: 	 Val. MSE_Loss: 0.0392
# on 43: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 43: Epoch: 44 | Time: 3m 47s
# on 43: 	Train MSE_Loss: 0.0343
# on 43: 	 Val. MSE_Loss: 0.0399
# on 44: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 44: Epoch: 45 | Time: 3m 51s
# on 44: 	Train MSE_Loss: 0.0343
# on 44: 	 Val. MSE_Loss: 0.0401
# on 45: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 45: Epoch: 46 | Time: 3m 37s
# on 45: 	Train MSE_Loss: 0.0342
# on 45: 	 Val. MSE_Loss: 0.0402
# on 46: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 46: Epoch: 47 | Time: 3m 45s
# on 46: 	Train MSE_Loss: 0.0342
# on 46: 	 Val. MSE_Loss: 0.0390
# on 47: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 47: Epoch: 48 | Time: 3m 36s
# on 47: 	Train MSE_Loss: 0.0343
# on 47: 	 Val. MSE_Loss: 0.0389
# on 48: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 48: Epoch: 49 | Time: 3m 38s
# on 48: 	Train MSE_Loss: 0.0342
# on 48: 	 Val. MSE_Loss: 0.0402
# on 49: Checkpoint saved to h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-last.pt
# on 49: Epoch: 50 | Time: 3m 47s
# on 49: 	Train MSE_Loss: 0.0343
# on 49: 	 Val. MSE_Loss: 0.0394
# training |████████████████████████████████████████| 50/50 [100%] in 3:17:38.7 (0.00/s)
# Loading checkpoint from h:\Projects\Edit-Novel-Seq2Seq-Module-master\Novel_Seq2Seq\trained_file\AT_featuresengineering_final-24to12-best.pt
# ✅ Loaded BEST model for final evaluation on test set.
# The mse is:0.03919957669668714.
# The mape is:18.741270239010703.
# The smape is:17.00669924952346.
