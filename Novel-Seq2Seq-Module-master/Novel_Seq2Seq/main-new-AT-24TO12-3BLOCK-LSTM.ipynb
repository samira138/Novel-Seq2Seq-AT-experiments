# %%
from google.colab import drive
drive.flush_and_unmount()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## اضافه کردن فولدر seq2seq-modual-master

# %%
import sys
sys.path.append("/content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master")

# %% [markdown]
# ### برای نمایش نوار پیشرفت زنده در هنگام آموزش مدل

# %%
pip install --upgrade pip setuptools wheel
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (25.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (80.9.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.45.1)

# %%
# !pip install alive_progress matplotlib
# Out:
# Requirement already satisfied: alive_progress in /usr/local/lib/python3.12/dist-packages (3.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: about-time==4.2.1 in /usr/local/lib/python3.12/dist-packages (from alive_progress) (4.2.1)
# Requirement already satisfied: graphemeu==0.7.2 in /usr/local/lib/python3.12/dist-packages (from alive_progress) (0.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %% [markdown]
# os : برای کار با مسیر فایل‌ها و پوشه‌ها

# %%
import torch
import torch.utils.data
import time
import numpy as np
import random
import os
import matplotlib.pyplot as plt
from alive_progress import alive_bar

# فراخوانی کلاس DataPrepare از ماژول preparedata
import prepare_data.prepare_data as prepare_data
from prepare_data.prepare_data import DataPrepare
from Novel_Seq2Seq.model import stack

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("DEVICE:", DEVICE)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1264: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)
# DEVICE: cuda

# %%
class MyMetrics:
    def __init__(self, y_pred, y_true, un_std):

        self.un_std = un_std
        self.y_pred = y_pred
        self.y_true = y_true
        self.metrics = {}
        self.mse()
        self.mape()
        self.smape()

    def mse(self):
        self.metrics['mse'] = np.mean((self.y_pred - self.y_true) ** 2)

    def mape(self):
        y_pred = self.un_std.un_standardize(x=self.y_pred)
        y_true = self.un_std.un_standardize(x=self.y_true)
        self.metrics['mape'] = np.mean(np.abs((y_pred - y_true) / (y_true))) * 100

    def smape(self):
        self.metrics['smape'] = 2.0 * np.mean(
            np.abs(self.y_pred - self.y_true) / (np.abs(self.y_pred) + np.abs(self.y_true))
        ) * 100

    def print_metrics(self):
        for key, values in self.metrics.items():
            print(f"The {key} is:{values}.")

# %%
os.chdir("/content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master")

# %%
class Train:
    def __init__(self, hyperparams, model, optimizer, loss_func):
        # پارامترهای دیتاست
        self.datapath       = hyperparams['datapath']
        self.datafile       = hyperparams['datafile']
        self.split_ratio    = hyperparams['split_ratio']

        # هایپرپارامترها
        self.N_EPOCHS       = hyperparams['N_EPOCHS']
        self.lr             = hyperparams['lr']
        self.batch_size     = hyperparams['batch_size']
        self.input_seqlen   = hyperparams['input_seqlen']
        self.predict_seqlen = hyperparams['predict_seqlen']
        self.features       = hyperparams['features']

        # آماده‌سازی داده
        self.dataprepare =  DataPrepare(
            datapath      = self.datapath,
            datafile      = self.datafile,
            input_steps   = self.input_seqlen,
            pred_horizion = self.predict_seqlen,
            split_ratio   = self.split_ratio
        )

        # دیتالودرها
        self.train_generator = None
        self.valid_generator = None
        self.test_generator  = None

        # مدل/بهینه‌ساز/تابع ضرر
        self.model     = model
        self.optimizer = optimizer
        self.loss_func = loss_func

        # loss تاریخچه‌ی توابع
        self.train_loss = []
        self.valid_loss = []
        self.mse        = 0

        #  مسیر ذخیره
        self.save_dir = os.path.join(os.getcwd(), "trained_file")
        os.makedirs(self.save_dir, exist_ok=True)

        # seed
        self._setup_seed(20)

        # ساخت دیتالودرها
        self._prepare_data()


#DataPrepare → داده خام رو می‌خونه، تمیز می‌کنه و تقسیم می‌کنه
#Datasets →  تبدیل می‌کنهPyTorch  داده رو به فرمت
#DataLoader → داده رو دسته‌بندی می‌کنه برای آموزش

    def _prepare_data(self):
        # خروجی prepare_data: (train_ip, train_op, valid_ip, valid_op, test_ip, test_op)
        tvt_data = self.dataprepare.prepare_data()
        train_dataset = prepare_data.Datasets(tvt_data[0], tvt_data[1])
        valid_dataset = prepare_data.Datasets(tvt_data[2], tvt_data[3])
        test_dataset  = prepare_data.Datasets(tvt_data[4], tvt_data[5])

        self.train_generator = torch.utils.data.DataLoader(train_dataset, batch_size=self.batch_size, shuffle=False)
        self.valid_generator = torch.utils.data.DataLoader(valid_dataset, batch_size=self.batch_size, shuffle=False)
        self.test_generator  = torch.utils.data.DataLoader(test_dataset,  batch_size=2048, shuffle=False)

    def _ckpt_path(self):
        # نام فایل چک‌پوینت
        name = f'{self.datafile}-{self.input_seqlen}to{self.predict_seqlen}.pt'
        return os.path.join(self.save_dir, name)

    #def save_state(self, state):
        #torch.save(state, self._ckpt_path())

    #def load_state(self):
        #print("Loading model and optimizer state")
        #state = torch.load(self._ckpt_path(), map_location="cpu")
        #self.model.load_state_dict(state['model'])
        #self.optimizer.load_state_dict(state['optimizer'])
        #self.train_loss = state['train_loss']
        #self.valid_loss = state['valid_loss']
        #self.mse        = state['mse']
        #self.dataprepare= state['dataprepare']

    def save_state(self, state, filename=None):
        filepath = self._ckpt_path()
        state["epoch"] = state.get("epoch", 0)   # شماره ایپاک هم ذخیره کن
        torch.save(state, filepath)
        print(f"Checkpoint saved to {filepath}")

    def load_state(self, filename=None):
        filepath = self._ckpt_path()
        print(f"Loading checkpoint from {filepath}")
        state = torch.load(filepath, map_location=DEVICE, weights_only=False)
        self.model.load_state_dict(state['model'])
        self.optimizer.load_state_dict(state['optimizer'])
        self.train_loss = state['train_loss']
        self.valid_loss = state['valid_loss']
        self.mse        = state['mse']
        #self.dataprepare= state['dataprepare']
        self.start_epoch = state.get("epoch_saved", 0)

    def _train(self):
        """
        params:
                None
        returns:
            每个样本的平均损失值
        """
        self.model.train()
        epoch_loss = 0

        for i, (x, y) in enumerate(self.train_generator):
            x = x.to(DEVICE)  # [batch_size, seq_len, feature]
            y = y.to(DEVICE)  # [batch_size, predict_seqlen]

            self.optimizer.zero_grad()
            # 输入到模型的是[batch_size, seq_len, features],模型输出是[batch_size,predict_seqlen, 1]
            output, residual = self.model(x)
            loss = self.loss_func(output.squeeze(dim=2), y) # + torch.mean(torch.abs(residual)) # output [batch_size, predict_seqlen]
            loss.backward()
            self.optimizer.step()
            epoch_loss += loss.item()
        # len(train_generator) 是 批次数量  即 样本总数/batch_size
        return epoch_loss / len(self.train_generator)



    def _evalute(self):
        self.model.eval()
        epoch_loss = 0.0
        with torch.no_grad():       #چوتن در پای تورچ گرادیان ها با گرادیان قبلی جمع میشود
            for x, y in self.test_generator:
                x = x.to(DEVICE)
                y = y.to(DEVICE)
                output, _ = self.model(x)  # [B, pred_len, 1]
                loss = self.loss_func(output.squeeze(2), y)
                epoch_loss += loss.item()
        return epoch_loss / len(self.test_generator)

    def _epoch_time(self, start_time, end_time):
        elapsed = end_time - start_time
        return int(elapsed // 60), int(elapsed % 60)
# قابلیت تکرارپذیری نتایج
    def _setup_seed(self, seed):
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        np.random.seed(seed)
        random.seed(seed)
        torch.backends.cudnn.deterministic = True

    def train_model(self):
        best_valid_loss = float('inf')
        start_epoch = getattr(self, "start_epoch", 0)   # اگر load_state شده باشه از ادامه شروع کن
        print(f'DEVICE: {DEVICE}')

        with alive_bar(total=self.N_EPOCHS, title='training') as bar:
            for epoch in range(start_epoch, self.N_EPOCHS):
              start_time = time.time()

              train_loss = self._train()
              valid_loss = self._evalute()

              self.train_loss.append(train_loss)
              self.valid_loss.append(valid_loss)

              epoch_mins, epoch_secs = self._epoch_time(start_time, time.time())

            # ذخیره بهترین مدل
              if best_valid_loss > valid_loss:
                best_valid_loss = valid_loss
                self.mse = valid_loss
                state = {
                    'model'      : self.model.state_dict(),
                    'optimizer'  : self.optimizer.state_dict(),
                    'train_loss' : self.train_loss,
                    'valid_loss' : self.valid_loss,
                    'dataprepare': self.dataprepare,
                    'mse'        : self.mse,
                    'epoch_saved': epoch + 1
                }
                self.save_state(state, filename=f"{self.datafile}-{self.input_seqlen}to{self.predict_seqlen}-best.pt")
                print(f"✅ Best model updated at epoch {epoch+1} | Val Loss: {valid_loss:.4f}")

            # ذخیره آخرین ایپاک (همیشه)
              last_state = {
                'model'      : self.model.state_dict(),
                'optimizer'  : self.optimizer.state_dict(),
                'train_loss' : self.train_loss,
                'valid_loss' : self.valid_loss,
                'dataprepare': self.dataprepare,
                'mse'        : valid_loss,
                'epoch_saved': epoch + 1
              }
              self.save_state(last_state, filename=f"{self.datafile}-{self.input_seqlen}to{self.predict_seqlen}-last.pt")

              print(f'Epoch: {epoch + 1:02} | Time: {epoch_mins}m {epoch_secs}s')
              print(f'\tTrain MSE_Loss: {train_loss:.4f}')
              print(f'\t Val. MSE_Loss: {valid_loss:.4f}')
              bar()



    def plot_loss(self, save: bool = False):
        fig = plt.figure(figsize=(15, 8), dpi=80)
        ax1 = fig.add_subplot(1, 1, 1)
        ax1.set_title('loss_value')
        ax1.set_xlabel('epoch')
        ax1.set_ylabel('loss')
        ax1.set_xlim(0, self.N_EPOCHS)
        ax1.plot(self.train_loss, marker='o', label='train_loss')
        ax1.plot(self.valid_loss, linestyle='--', alpha=0.7, label='valid_loss')
        ax1.legend(loc='upper left')
        if save:
            plt.savefig('loss_value.jpg', dpi=400, bbox_inches='tight')
        plt.show()

    def predict(self):
        """
        :return: y_hat, y  → هر کدام [samples, pred_len]
        """
        self.model.eval()
        with torch.no_grad():
            for x, y in self.test_generator:
                x = x.to(DEVICE)
                y = y.to(DEVICE)
                y_hat, _ = self.model(x)              # [B, pred_len, 1]
                y_hat = y_hat.squeeze(2)              # [B, pred_len]
                break
        return y_hat.cpu().numpy(), y.cpu().numpy()

# %%
# هایپرپارامترها (طبق مقاله مقادیر H=3/6/12/24 را تغییر بده)
HyperParams = {
    'datapath'       : "/content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/prepare_data/data/",
    'datafile'       : "AT",          # یکی از CH.csv / DE.csv / AT.csv
    'split_ratio'    : (0.8, 0.1, 0.1),
    'N_EPOCHS'       : 50,                 # برای تست سریع؛ بعداً بیشترش کن
    'lr'             : 1e-3,
    'batch_size'     : 64,
    'input_seqlen'   : 24,
    'predict_seqlen' : 12,
    'features'       : 3,                 # LOAD, TEMP, WIND
}


def main(LOAD_PREV=False):
    # ساخت مدل مطابق کد اصلی (stack.Stack)
    model = stack.Stack(
        input_size      = HyperParams['features'],
        encoder_channels= [4,6,8,12],
        input_seqlen    = HyperParams['input_seqlen'],
        forecast_seqlen = HyperParams['predict_seqlen']
    ).to(DEVICE)

    optimizer = torch.optim.Adam(model.parameters(), lr=HyperParams['lr'])
    loss_func = torch.nn.MSELoss(reduction='mean')

    T = Train(hyperparams=HyperParams, model=model, optimizer=optimizer, loss_func=loss_func)


    if LOAD_PREV:
        print("🔄 Loading checkpoint and continuing training...")
        T.load_state()
        #T.train_model()
    else:
        print("🆕 Starting training from scratch...")
        T.train_model()

    # ارزیابی
    y_hat, y = T.predict()
    metrics = MyMetrics(y_hat, y, T.dataprepare)
    metrics.print_metrics()
    T.plot_loss()

# %%
# فهمیدن تعداد بلوک ها
ckpt = "/content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/CH-12to3.pt"
state = torch.load(ckpt, map_location="cpu", weights_only=False)  # حتماً False

sd = state["model"]  # state_dictِ مدل
blocks = sorted({k.split('.')[0] for k in sd.keys() if k.startswith('block_')})
print(blocks)  # مثلا ['block_1', 'block_2']
# Out:
# ['block_1', 'block_2']
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 0.23.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
main()
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 🆕 Starting training from scratch...
# DEVICE: cuda
# on 0: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 0: ✅ Best model updated at epoch 1 | Val Loss: 0.0420
# on 0: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 0: Epoch: 01 | Time: 1m 51s
# on 0: 	Train MSE_Loss: 0.0315
# on 0: 	 Val. MSE_Loss: 0.0420
# on 1: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 1: ✅ Best model updated at epoch 2 | Val Loss: 0.0222
# on 1: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 1: Epoch: 02 | Time: 1m 51s
# on 1: 	Train MSE_Loss: 0.0215
# on 1: 	 Val. MSE_Loss: 0.0222
# on 2: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 2: ✅ Best model updated at epoch 3 | Val Loss: 0.0172
# on 2: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 2: Epoch: 03 | Time: 1m 50s
# on 2: 	Train MSE_Loss: 0.0132
# on 2: 	 Val. MSE_Loss: 0.0172
# on 3: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 3: ✅ Best model updated at epoch 4 | Val Loss: 0.0146
# on 3: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 3: Epoch: 04 | Time: 1m 51s
# on 3: 	Train MSE_Loss: 0.0111
# on 3: 	 Val. MSE_Loss: 0.0146
# on 4: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 4: ✅ Best model updated at epoch 5 | Val Loss: 0.0131
# on 4: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 4: Epoch: 05 | Time: 1m 52s
# on 4: 	Train MSE_Loss: 0.0098
# on 4: 	 Val. MSE_Loss: 0.0131
# on 5: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 5: ✅ Best model updated at epoch 6 | Val Loss: 0.0119
# on 5: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 5: Epoch: 06 | Time: 1m 51s
# on 5: 	Train MSE_Loss: 0.0090
# on 5: 	 Val. MSE_Loss: 0.0119
# on 6: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 6: ✅ Best model updated at epoch 7 | Val Loss: 0.0111
# on 6: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 6: Epoch: 07 | Time: 1m 52s
# on 6: 	Train MSE_Loss: 0.0085
# on 6: 	 Val. MSE_Loss: 0.0111
# on 7: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 7: ✅ Best model updated at epoch 8 | Val Loss: 0.0101
# on 7: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 7: Epoch: 08 | Time: 1m 50s
# on 7: 	Train MSE_Loss: 0.0080
# on 7: 	 Val. MSE_Loss: 0.0101
# on 8: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 8: ✅ Best model updated at epoch 9 | Val Loss: 0.0098
# on 8: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 8: Epoch: 09 | Time: 1m 51s
# on 8: 	Train MSE_Loss: 0.0076
# on 8: 	 Val. MSE_Loss: 0.0098
# on 9: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 9: ✅ Best model updated at epoch 10 | Val Loss: 0.0091
# on 9: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 9: Epoch: 10 | Time: 1m 50s
# on 9: 	Train MSE_Loss: 0.0074
# on 9: 	 Val. MSE_Loss: 0.0091
# on 10: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 10: ✅ Best model updated at epoch 11 | Val Loss: 0.0086
# on 10: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 10: Epoch: 11 | Time: 1m 50s
# on 10: 	Train MSE_Loss: 0.0072
# on 10: 	 Val. MSE_Loss: 0.0086
# on 11: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 11: ✅ Best model updated at epoch 12 | Val Loss: 0.0084
# on 11: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 11: Epoch: 12 | Time: 1m 48s
# on 11: 	Train MSE_Loss: 0.0071
# on 11: 	 Val. MSE_Loss: 0.0084
# on 12: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 12: ✅ Best model updated at epoch 13 | Val Loss: 0.0079
# on 12: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 12: Epoch: 13 | Time: 1m 49s
# on 12: 	Train MSE_Loss: 0.0069
# on 12: 	 Val. MSE_Loss: 0.0079
# on 13: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 13: ✅ Best model updated at epoch 14 | Val Loss: 0.0079
# on 13: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 13: Epoch: 14 | Time: 1m 50s
# on 13: 	Train MSE_Loss: 0.0068
# on 13: 	 Val. MSE_Loss: 0.0079
# on 14: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 14: Epoch: 15 | Time: 1m 49s
# on 14: 	Train MSE_Loss: 0.0066
# on 14: 	 Val. MSE_Loss: 0.0081
# on 15: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 15: ✅ Best model updated at epoch 16 | Val Loss: 0.0075
# on 15: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 15: Epoch: 16 | Time: 1m 47s
# on 15: 	Train MSE_Loss: 0.0064
# on 15: 	 Val. MSE_Loss: 0.0075
# on 16: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 16: ✅ Best model updated at epoch 17 | Val Loss: 0.0072
# on 16: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 16: Epoch: 17 | Time: 1m 49s
# on 16: 	Train MSE_Loss: 0.0064
# on 16: 	 Val. MSE_Loss: 0.0072
# on 17: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 17: Epoch: 18 | Time: 1m 49s
# on 17: 	Train MSE_Loss: 0.0062
# on 17: 	 Val. MSE_Loss: 0.0072
# on 18: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 18: ✅ Best model updated at epoch 19 | Val Loss: 0.0070
# on 18: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 18: Epoch: 19 | Time: 1m 49s
# on 18: 	Train MSE_Loss: 0.0061
# on 18: 	 Val. MSE_Loss: 0.0070
# on 19: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 19: ✅ Best model updated at epoch 20 | Val Loss: 0.0068
# on 19: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 19: Epoch: 20 | Time: 1m 47s
# on 19: 	Train MSE_Loss: 0.0059
# on 19: 	 Val. MSE_Loss: 0.0068
# on 20: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 20: Epoch: 21 | Time: 1m 48s
# on 20: 	Train MSE_Loss: 0.0057
# on 20: 	 Val. MSE_Loss: 0.0072
# on 21: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 21: ✅ Best model updated at epoch 22 | Val Loss: 0.0067
# on 21: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 21: Epoch: 22 | Time: 1m 49s
# on 21: 	Train MSE_Loss: 0.0055
# on 21: 	 Val. MSE_Loss: 0.0067
# on 22: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 22: Epoch: 23 | Time: 1m 48s
# on 22: 	Train MSE_Loss: 0.0053
# on 22: 	 Val. MSE_Loss: 0.0071
# on 23: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 23: Epoch: 24 | Time: 1m 48s
# on 23: 	Train MSE_Loss: 0.0052
# on 23: 	 Val. MSE_Loss: 0.0070
# on 24: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 24: Epoch: 25 | Time: 1m 49s
# on 24: 	Train MSE_Loss: 0.0050
# on 24: 	 Val. MSE_Loss: 0.0071
# on 25: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 25: Epoch: 26 | Time: 1m 49s
# on 25: 	Train MSE_Loss: 0.0050
# on 25: 	 Val. MSE_Loss: 0.0072
# on 26: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 26: ✅ Best model updated at epoch 27 | Val Loss: 0.0061
# on 26: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 26: Epoch: 27 | Time: 1m 47s
# on 26: 	Train MSE_Loss: 0.0048
# on 26: 	 Val. MSE_Loss: 0.0061
# on 27: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 27: Epoch: 28 | Time: 1m 49s
# on 27: 	Train MSE_Loss: 0.0048
# on 27: 	 Val. MSE_Loss: 0.0064
# on 28: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 28: Epoch: 29 | Time: 1m 49s
# on 28: 	Train MSE_Loss: 0.0047
# on 28: 	 Val. MSE_Loss: 0.0062
# on 29: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 29: Epoch: 30 | Time: 1m 48s
# on 29: 	Train MSE_Loss: 0.0047
# on 29: 	 Val. MSE_Loss: 0.0066
# on 30: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 30: Epoch: 31 | Time: 1m 47s
# on 30: 	Train MSE_Loss: 0.0047
# on 30: 	 Val. MSE_Loss: 0.0064
# on 31: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 31: Epoch: 32 | Time: 1m 49s
# on 31: 	Train MSE_Loss: 0.0047
# on 31: 	 Val. MSE_Loss: 0.0062
# on 32: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 32: ✅ Best model updated at epoch 33 | Val Loss: 0.0059
# on 32: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 32: Epoch: 33 | Time: 1m 49s
# on 32: 	Train MSE_Loss: 0.0046
# on 32: 	 Val. MSE_Loss: 0.0059
# on 33: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 33: ✅ Best model updated at epoch 34 | Val Loss: 0.0056
# on 33: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 33: Epoch: 34 | Time: 1m 50s
# on 33: 	Train MSE_Loss: 0.0045
# on 33: 	 Val. MSE_Loss: 0.0056
# on 34: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 34: Epoch: 35 | Time: 1m 47s
# on 34: 	Train MSE_Loss: 0.0044
# on 34: 	 Val. MSE_Loss: 0.0059
# on 35: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 35: ✅ Best model updated at epoch 36 | Val Loss: 0.0055
# on 35: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 35: Epoch: 36 | Time: 1m 48s
# on 35: 	Train MSE_Loss: 0.0045
# on 35: 	 Val. MSE_Loss: 0.0055
# on 36: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 36: ✅ Best model updated at epoch 37 | Val Loss: 0.0054
# on 36: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 36: Epoch: 37 | Time: 1m 49s
# on 36: 	Train MSE_Loss: 0.0044
# on 36: 	 Val. MSE_Loss: 0.0054
# on 37: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 37: ✅ Best model updated at epoch 38 | Val Loss: 0.0053
# on 37: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 37: Epoch: 38 | Time: 1m 47s
# on 37: 	Train MSE_Loss: 0.0044
# on 37: 	 Val. MSE_Loss: 0.0053
# on 38: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 38: ✅ Best model updated at epoch 39 | Val Loss: 0.0052
# on 38: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 38: Epoch: 39 | Time: 1m 48s
# on 38: 	Train MSE_Loss: 0.0043
# on 38: 	 Val. MSE_Loss: 0.0052
# on 39: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 39: ✅ Best model updated at epoch 40 | Val Loss: 0.0049
# on 39: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 39: Epoch: 40 | Time: 1m 48s
# on 39: 	Train MSE_Loss: 0.0043
# on 39: 	 Val. MSE_Loss: 0.0049
# on 40: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 40: ✅ Best model updated at epoch 41 | Val Loss: 0.0049
# on 40: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 40: Epoch: 41 | Time: 1m 48s
# on 40: 	Train MSE_Loss: 0.0043
# on 40: 	 Val. MSE_Loss: 0.0049
# on 41: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 41: ✅ Best model updated at epoch 42 | Val Loss: 0.0048
# on 41: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 41: Epoch: 42 | Time: 1m 47s
# on 41: 	Train MSE_Loss: 0.0042
# on 41: 	 Val. MSE_Loss: 0.0048
# on 42: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 42: Epoch: 43 | Time: 1m 48s
# on 42: 	Train MSE_Loss: 0.0042
# on 42: 	 Val. MSE_Loss: 0.0050
# on 43: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 43: ✅ Best model updated at epoch 44 | Val Loss: 0.0048
# on 43: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 43: Epoch: 44 | Time: 1m 50s
# on 43: 	Train MSE_Loss: 0.0042
# on 43: 	 Val. MSE_Loss: 0.0048
# on 44: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 44: Epoch: 45 | Time: 1m 49s
# on 44: 	Train MSE_Loss: 0.0041
# on 44: 	 Val. MSE_Loss: 0.0049
# on 45: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 45: Epoch: 46 | Time: 1m 48s
# on 45: 	Train MSE_Loss: 0.0041
# on 45: 	 Val. MSE_Loss: 0.0048
# on 46: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 46: Epoch: 47 | Time: 1m 50s
# on 46: 	Train MSE_Loss: 0.0041
# on 46: 	 Val. MSE_Loss: 0.0048
# on 47: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 47: ✅ Best model updated at epoch 48 | Val Loss: 0.0046
# on 47: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 47: Epoch: 48 | Time: 1m 49s
# on 47: 	Train MSE_Loss: 0.0041
# on 47: 	 Val. MSE_Loss: 0.0046
# on 48: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 48: Epoch: 49 | Time: 1m 50s
# on 48: 	Train MSE_Loss: 0.0040
# on 48: 	 Val. MSE_Loss: 0.0047
# on 49: Checkpoint saved to /content/drive/MyDrive/code1-seq-to-seq/Novel-Seq2Seq-Module-master/trained_file/AT-24to12.pt
# on 49: Epoch: 50 | Time: 1m 47s
# on 49: 	Train MSE_Loss: 0.0040
# on 49: 	 Val. MSE_Loss: 0.0048
# training |████████████████████████████████████████| 50/50 [100%] in 1:31:25.2 (0.01/s)
# The mse is:0.0038587441831330026.
# The mape is:4.666500021768932.
# The smape is:8.798140435513728.
